# %% [markdown]
# <h1>Ramanujan Filter Banks<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Example-demo-1" data-toc-modified-id="Example-demo-1-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Example demo 1</a></span></li><li><span><a href="#Example-demo-2" data-toc-modified-id="Example-demo-2-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Example demo 2</a></span></li><li><span><a href="#Example-demo-2-with-diff-periods" data-toc-modified-id="Example-demo-2-with-diff-periods-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Example demo 2 with diff periods</a></span></li></ul></div>

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys, scipy
from scipy import linalg as LA
import spkit as sp

# %% [markdown]
# ## Example demo 1

# %%
sp.RFB_example_1(period=10, SNR=0, seed=10)
# Out:
# top 10 periods:  [10  5 11 18 17 16 15 14 13 12]

# %% [markdown]
# ## Example demo 2

# %%
sp.RFB_example_2(periods=[3, 7, 11], signal_length=100, SNR=10, seed=15)
# Out:
# top 10 periods:  [ 3  7 11  2  6  5 10 15  4  8]
# top 10 periods:  [ 3  2 89 65 61 67 52 71 70 79]
# top 10 periods:  [ 3  7  2  6  5 11  4  8 10 13]
# top 10 periods:  [ 3 11  7 28 50 90 34 26 27 29]

# %% [markdown]
# ## Example demo 2 with diff periods

# %%
sp.RFB_example_2(periods=[3,7,14], signal_length=100, SNR=10, seed=15)
# Out:
# top 10 periods:  [ 3  2  6  7 10  5 11 13 15 16]
# top 10 periods:  [ 2  3 89 65 67 68 64 61 79 87]
# top 10 periods:  [ 3  2  6  7  5 11 10 13  9  8]
# top 10 periods:  [ 7  3 14 90 34 26 27 28 29 30]
