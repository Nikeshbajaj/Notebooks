# %% [markdown]
# <span style="color:green;float:right">https://phyaat.github.io</span>

# %% [markdown]
# # Using External Libraries
#
# In this notebook, we explain how to extract the signals preprocess with external libraries and do predictive modeling.

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Read-the-data-of-subject=1" data-toc-modified-id="Read-the-data-of-subject=1-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Read the data of subject=1</a></span></li><li><span><a href="#Extract-Raw-Signals" data-toc-modified-id="Extract-Raw-Signals-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Extract Raw Signals</a></span></li><li><span><a href="#Artifact-removal-using-ICA" data-toc-modified-id="Artifact-removal-using-ICA-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Artifact removal using ICA</a></span></li><li><span><a href="#T3:-Semanticity-Classification" data-toc-modified-id="T3:-Semanticity-Classification-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>T3: Semanticity Classification</a></span></li><li><span><a href="#Task=4---LWR-classification" data-toc-modified-id="Task=4---LWR-classification-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Task=4 - LWR classification</a></span></li><li><span><a href="#Task=3---Semanticity-classification" data-toc-modified-id="Task=3---Semanticity-classification-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Task=3 - Semanticity classification</a></span></li><li><span><a href="#Task=2---Noise-level-prediction-:-Regression" data-toc-modified-id="Task=2---Noise-level-prediction-:-Regression-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Task=2 - Noise level prediction : Regression</a></span></li><li><span><a href="#Task=1,-Attention-Level-prediction:--Regression" data-toc-modified-id="Task=1,-Attention-Level-prediction:--Regression-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Task=1, Attention Level prediction:  Regression</a></span></li></ul></div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn import svm

# %%
import phyaat
print('Version :' ,phyaat.__version__)
import phyaat as ph
# Out:
# PhyAAt Processing lib Loaded...
# Version : 0.0.2

# %% [markdown]
# ## Read the data of subject=1

# %%
dirPath = ph.download_data(baseDir='../PhyAAt_Data', subject=1,verbose=0,overwrite=False)

baseDir='../PhyAAt_Data'

SubID = ph.ReadFilesPath(baseDir)

Subj = ph.Subject(SubID[1])
# Out:
# Total Subjects :  1

# %%
Subj.filter_EEG(band =[0.5],btype='highpass',order=5)

# %% [markdown]
# ## Extract Raw Signals

# %%
XE = Subj.getEEG().to_numpy()
XG = Subj.getGSR().to_numpy()
XP = Subj.getPPG().to_numpy()

# %%
plt.figure(figsize=(13,3))
plt.plot(XE[:10000,:]+np.arange(14)*100)
plt.show()

# %%
plt.figure(figsize=(12,3))
plt.plot(XG[:10000,:])
plt.show()

# %%
plt.figure(figsize=(12,3))
plt.plot(XP[:10000,:])
plt.show()
